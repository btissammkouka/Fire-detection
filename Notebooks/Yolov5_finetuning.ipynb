# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision
# !pip install opencv-python-headless
# !pip install matplotlib seaborn scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17485, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 17485 (delta 76), reused 29 (delta 29), pack-reused 17380 (from 4)
# Receiving objects: 100% (17485/17485), 16.35 MiB | 29.95 MiB/s, done.
# Resolving deltas: 100% (11987/11987), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import zipfile
zip_path = '/content/archive.zip'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/Fire-Detection/data.yaml --weights yolov5s.pt --name fire_detector
# Out:
# Streaming output truncated to the last 5000 lines.
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/63 [00:00<?, ?it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       81/99      4.51G    0.02111    0.01283          0         49        640:   2% 1/63 [00:00<00:12,  4.89it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/63 [00:00<?, ?it/s]/content/yolov5/train.py:413: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Chemin vers les résultats (ajuste "exp" si nécessaire)
results_path = "/content/yolov5/runs/train/fire_detector/results.png"

# Afficher l'image des courbes
img = mpimg.imread(results_path)
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# Afficher la matrice de confusion
confusion_matrix_path = "//content/yolov5/runs/train/fire_detector/confusion_matrix.png"
img = mpimg.imread(confusion_matrix_path)
plt.figure(figsize=(8, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Évaluer sur l'ensemble de test
# !python val.py --weights /content/yolov5/runs/train/fire_detector/weights/best.pt --data /content/Fire-Detection/data.yaml --img 640 --task test
# Out:
# val: data=/content/Fire-Detection/data.yaml, weights=['/content/yolov5/runs/train/fire_detector/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-418-ga493afe1 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/Fire-Detection/test/labels... 751 images, 2 backgrounds, 0 corrupt: 100% 751/751 [00:00<00:00, 1326.44it/s]
# test: New cache created: /content/Fire-Detection/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 24/24 [00:11<00:00,  2.04it/s]
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/fire_detector/weights/best.pt --data /content/Fire-Detection/data.yaml --img 640 --task test

# %%
# !zip -r /content/yolov5.zip /content/yolov5
# Out:
# updating: content/yolov5/ (stored 0%)
# updating: content/yolov5/yolov5s.pt (deflated 9%)
# updating: content/yolov5/utils/ (stored 0%)
# updating: content/yolov5/utils/general.py (deflated 66%)
# updating: content/yolov5/utils/augmentations.py (deflated 66%)
# updating: content/yolov5/utils/metrics.py (deflated 66%)
# updating: content/yolov5/utils/aws/ (stored 0%)
# updating: content/yolov5/utils/aws/userdata.sh (deflated 46%)
# updating: content/yolov5/utils/aws/resume.py (deflated 45%)
# updating: content/yolov5/utils/aws/mime.sh (deflated 45%)
# updating: content/yolov5/utils/aws/__init__.py (deflated 14%)
# updating: content/yolov5/utils/activations.py (deflated 70%)
# updating: content/yolov5/utils/plots.py (deflated 64%)
# updating: content/yolov5/utils/downloads.py (deflated 62%)
# updating: content/yolov5/utils/callbacks.py (deflated 68%)
# updating: content/yolov5/utils/__pycache__/ (stored 0%)
# ...
